# %%
import os
import json
import pandas as pd

def calculate_fantasy_points_from_json(json_file):
    with open(json_file, 'r') as f:
        match_data = json.load(f)

    # Extract match date
    match_date = match_data.get("info", {}).get("dates", ["Unknown"])[0]

    # Initialize fantasy points
    players = {player: 0 for team in match_data['info']['players'].values() for player in team}
    batter_scores = {player: 0 for player in players}
    bowler_wickets = {player: 0 for player in players}
    fielder_catches = {player: 0 for player in players}
    batter_balls = {player: 0 for player in players}
    bowler_runs = {player: 0 for player in players}
    bowler_balls = {player: 0 for player in players}

    # Process deliveries
    for inning in match_data.get('innings', []):
        for over in inning['overs']:
            for delivery in over['deliveries']:
                batter = delivery['batter']
                bowler = delivery['bowler']
                runs = delivery['runs']['batter']
                wickets = delivery.get('wickets', [])

                # Skip missing players
                if batter not in players:
                    continue
                
                # Batting points
                players[batter] += BAT_POINT_RUN * runs
                batter_scores[batter] += runs
                batter_balls[batter] += 1
                if runs >= 6:
                    players[batter] += BAT_POINT_SIX
                elif runs >= 4:
                    players[batter] += BAT_POINT_BOUNDARY

                if any(wicket['player_out'] == batter for wicket in wickets) and batter_scores[batter] == 0:
                    players[batter] += BAT_POINT_DUCK

                # Bowling and fielding points
                if bowler in players:
                    for wicket in wickets:
                        if wicket['kind'] != 'run out':
                            players[bowler] += BOWL_POINT_WICKET
                            bowler_wickets[bowler] += 1
                            if wicket['kind'] in ['lbw', 'bowled']:
                                players[bowler] += BOWL_POINT_BONUS

                for wicket in wickets:
                    for fielder in wicket.get('fielders', []):
                        field_name = fielder['name']
                        if field_name in players:
                            if wicket['kind'] == 'caught':
                                players[field_name] += FIELD_POINT_CATCH
                                fielder_catches[field_name] += 1
                            elif wicket['kind'] == 'stumped':
                                players[field_name] += FIELD_POINT_STUMPING
                            elif wicket['kind'] == 'run out':
                                if 'direct_hit' in fielder:
                                    players[field_name] += FIELD_POINT_RUN_OUT_DIRECT
                                else:
                                    players[field_name] += FIELD_POINT_RUN_OUT

                # Update bowler stats
                if bowler in players:
                    bowler_runs[bowler] += runs
                    bowler_balls[bowler] += 1

    # Additional scoring
    for player in batter_scores:
        if batter_scores[player] >= 100:
            players[player] += BAT_POINT_CENTURY
        elif batter_scores[player] >= 50:
            players[player] += BAT_POINT_HALF_CENTURY

    for player in fielder_catches:
        if fielder_catches[player] >= 3:
            players[player] += FIELD_POINT_3_CATCH_BONUS

    for player in bowler_wickets:
        if bowler_wickets[player] >= 5:
            players[player] += BOWL_POINT_5_WICKET_BONUS
        elif bowler_wickets[player] >= 4:
            players[player] += BOWL_POINT_4_WICKET_BONUS

    for player in bowler_runs:
        if bowler_balls[player] >= 30:
            economy_rate = bowler_runs[player] / (bowler_balls[player] / 6)
            if economy_rate < 2.5:
                players[player] += ECONOMY_POINT_2_5
            elif economy_rate < 3.5:
                players[player] += ECONOMY_POINT_3_49
            elif economy_rate < 4.5:
                players[player] += ECONOMY_POINT_4_5
            elif economy_rate >= 8 and economy_rate < 9:
                players[player] += ECONOMY_POINT_8_9
            elif economy_rate >= 9:
                players[player] += ECONOMY_POINT_ABOVE_9

    for player in batter_scores:
        if batter_balls[player] >= 20:
            strike_rate = (batter_scores[player] / batter_balls[player]) * 100
            if strike_rate > 140:
                players[player] += STRIKE_RATE_POINT_140
            elif strike_rate > 120:
                players[player] += STRIKE_RATE_POINT_120_140
            elif strike_rate > 100:
                players[player] += STRIKE_RATE_POINT_100_120
            elif strike_rate >= 40:
                players[player] += STRIKE_RATE_POINT_40_50
            elif strike_rate >= 30:
                players[player] += STRIKE_RATE_POINT_30_40
            elif strike_rate < 30:
                players[player] += STRIKE_RATE_POINT_BELOW_30

    # Convert to DataFrame
    df = pd.DataFrame({
        "Player Name": list(players.keys()),
        "Fantasy Points": list(players.values()),
        "Match Date": match_date
    })

    return df

# Processing all match files
def process_all_matches(folders):
    dataframes = []

    for folder in folders:
        for root, _, files in os.walk(folder):
            for file in files:
                if file.endswith(".json"):  # Only process JSON files
                    file_path = os.path.join(root, file)
                    try:
                        df = calculate_fantasy_points_from_json(file_path)
                        dataframes.append(df)
                    except Exception as e:
                        print(f"Error processing {file_path}: {e}")

    # Combine all DataFrames into one
    final_df = pd.concat(dataframes, ignore_index=True)
    return final_df

# Example usage
folders = ["data1_json","data2_json","data3_json"]  # Replace with actual folder path
df = process_all_matches(folders)
df.to_csv("fantasy_points_data.csv", index=False)
# Out:
# Error processing data1_json/65240.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66357.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65708.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64825.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65255.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66381.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65635.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66205.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65264.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66372.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65256.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64894.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66210.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65283.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65265.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64874.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64898.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65278.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66301.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66204.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64906.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65636.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65807.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64849.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64865.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64913.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66196.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65805.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64829.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66380.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66206.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66295.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64881.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65718.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65649.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64819.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65261.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64924.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65238.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64935.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64887.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66375.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64848.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65244.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64923.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66297.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65646.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65637.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64943.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65250.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66305.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65656.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64857.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65273.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65803.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64836.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65642.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64871.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65716.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66383.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65272.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65259.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65254.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66296.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64851.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66209.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66368.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64889.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64842.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64832.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65662.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64939.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64925.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66364.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64853.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65664.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66207.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65653.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65242.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65236.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64917.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64922.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65235.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64883.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65809.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64934.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65032.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64864.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66379.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64817.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64855.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65271.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64897.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64845.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66294.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64929.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66374.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65237.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64896.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64933.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64833.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64919.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64841.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64882.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65258.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64905.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65270.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65262.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64928.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65281.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65666.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65239.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64815.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64844.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66201.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64820.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65033.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65246.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66358.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65640.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65660.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64850.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65285.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66385.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66365.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66311.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64816.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64838.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64926.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65655.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65241.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65252.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65251.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65249.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65644.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66203.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65641.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64846.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65645.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65267.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65659.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66356.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64870.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66197.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65248.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65257.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64941.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64910.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65034.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66363.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64830.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65634.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64932.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66202.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64862.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65279.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66377.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64884.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65029.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65804.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65648.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64839.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64899.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66208.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65276.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64927.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65808.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66378.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66369.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65647.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64814.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64936.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65030.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65268.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64826.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64885.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65266.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64831.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65275.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65643.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64837.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64872.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64852.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66302.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64840.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65806.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65282.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65661.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64827.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66198.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66361.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65638.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65280.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65031.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66309.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64907.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64914.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66386.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65714.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65260.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65652.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66367.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65286.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65263.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64901.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64891.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64942.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66306.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66366.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65639.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64911.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66293.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66299.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65713.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65247.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66200.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65665.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64900.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/64843.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65245.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/66304.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65269.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65284.json: name 'BAT_POINT_RUN' is not defined
# Error processing data1_json/65277.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/249755.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/518962.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/514037.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/656477.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/209582.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/597923.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/401075.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/291370.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/696759.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/361046.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/800473.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/476600.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/534210.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/258476.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/361047.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/422628.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/567372.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/247498.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/350477.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/527016.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/313993.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/489224.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/249759.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/410338.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/386534.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/343734.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/295785.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/224227.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/249379.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json
json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/727923.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/226381.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/249212.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/643677.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/690357.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/690355.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/239917.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/540168.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/727937.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/293482.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/858489.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/914209.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/433593.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/743945.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/483126.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/919607.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/426405.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/736445.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/416236.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/335347.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/667891.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/932861.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/433588.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/225959.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/258465.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/238213.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/566944.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/439151.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/656485.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/375457.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/319147.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/319143.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/522249.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/571146.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/452149.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/264069.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/636535.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/433559.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/736453.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/742623.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/439142.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/914233.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/226364.json: name 'BAT_POINT_RUN' is not defined
# Error processing data2_json/325581.json: name 'BAT_POINT_RUN' is not defined
# ...
# Error processing data3_json/1120286.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1428960.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1185319.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1031673.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1308248.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1428957.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1365093.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1315040.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377748.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1206062.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1153844.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1348328.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1142920.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1214667.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1341973.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1341976.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1375848.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144987.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1022361.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1168243.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1140383.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1341975.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1168246.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1428958.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377005.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1140381.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1450696.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1312805.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1420529.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1109606.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144530.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144496.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1365102.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377770.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1421073.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1153244.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1373574.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1153840.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1365100.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1050223.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1185311.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1119541.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1133003.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1302619.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144986.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1154649.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1358074.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377750.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144522.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1153845.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144171.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1213871.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1358083.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1115805.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1133025.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1312800.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1420533.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1104479.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1119499.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1331367.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1109605.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1365099.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144529.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1198247.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1029823.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1027317.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1276295.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1262757.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1007651.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1302627.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144528.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1456444.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1302626.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1142588.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1388394.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1317481.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1384427.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377007.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1098206.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1019975.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1358082.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1146720.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1277086.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1122726.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1336054.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1174240.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1153842.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144491.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1375847.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1187027.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1388393.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1312802.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1078661.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1157378.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1358089.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144499.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1198240.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1120091.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1030219.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1302349.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1211171.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1267678.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1303311.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1115804.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1450695.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1420220.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1426549.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1412540.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1244524.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1027319.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1322035.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1408107.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1388414.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1075504.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1168517.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1262344.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1196675.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1317902.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1445034.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1251962.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1072312.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1130741.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1168518.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1115779.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144527.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1033361.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1317491.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1203673.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1080630.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1215122.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1451818.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1206063.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1131277.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1431088.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1168519.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1122280.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1000889.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144519.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1419827.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1026851.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1365552.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144512.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1450702.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1317912.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1185312.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1275249.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1317153.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1322036.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1179275.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1381216.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144157.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1384408.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1115797.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1384428.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1196671.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1120092.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1169332.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1098207.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1153841.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1302621.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1168511.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1223955.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377778.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1068737.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1421071.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1322031.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1152841.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1384401.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1395701.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1152844.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1384432.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1144501.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1158067.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1030221.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1322278.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1146722.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1020037.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377757.json: name 'BAT_POINT_RUN' is not defined
# Error processing data3_json/1377752.json: name 'BAT_POINT_RUN' is not defined
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 152
#     150 # Example usage
#     151 folders = ["data1_json","data2_json","data3_json"]  # Replace with actual folder path
# --> 152 df = process_all_matches(folders)
#     153 df.to_csv("fantasy_points_data.csv", index=False)
#
# Cell In[1], line 147, in process_all_matches(folders)
#     144                     print(f"Error processing {file_path}: {e}")
#     146 # Combine all DataFrames into one
# --> 147 final_df = pd.concat(dataframes, ignore_index=True)
#     148 return final_df
#
# File ~/test/lib/python3.10/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/test/lib/python3.10/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/test/lib/python3.10/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
