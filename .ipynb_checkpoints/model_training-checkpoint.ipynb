# %%
import numpy as np 
import pandas as pd 
import xgboost as xgb 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error 
import warnings 
warnings.filterwarnings('ignore')

# %%
x_train=pd.read_csv('x_train.csv') 
y_train=pd.read_csv('y_train.csv') 
x_test=x_train.iloc[45000:,:].to_numpy() 
y_test=y_train.iloc[45000:].to_numpy() 
x_train=x_train.iloc[:45000,:].to_numpy() 
y_train=y_train.iloc[:45000].to_numpy()

# %%
x_train = x_train.reshape(x_train.shape[0], -1)
dtrain = xgb.DMatrix(x_train, label=y_train)

params = {
    'objective': 'reg:squarederror',  # Regression objective for continuous target
    'eval_metric': 'rmse',             # Mean Absolute Error, suitable for regression
    'max_depth': 5,                   # Slightly deeper tree depth to capture more complexity
    'learning_rate': 0.001,            # Lower learning rate for better generalization
    'n_estimators': 250,              # Increase to allow the model to learn more from data
    'subsample': 0.6,                 # Use 60% of data per tree for better generalization
    'colsample_bytree': 0.8,          # Use 80% of features per tree
    'reg_alpha': 1,                 # L1 regularization to reduce overfitting
    'reg_lambda': 1                  # L2 regularization to control complexity
}  


watchlist = [(dtrain, 'train')]


num_round = 1000 
model = xgb.train(params, dtrain, num_round)

# %%
x_test = x_test.reshape(x_test.shape[0], -1)
dtest = xgb.DMatrix(x_test)
y_pred = model.predict(dtest)

# %%
import numpy as np

def process_chunks(y_pred, y_test, chunk_size=22):
    length = (len(y_pred) // chunk_size) * chunk_size  # Exclude the remainder
    y_pred_chunks = [y_pred[i:i + chunk_size] for i in range(0, length, chunk_size)]
    y_test_chunks = [y_test[i:i + chunk_size] for i in range(0, length, chunk_size)]

    top_11_indices_pred = []
    sorted_y_test_chunks = []  
    sorted_y_pred_chunks = [] 
    for chunk in y_pred_chunks:
        sorted_indices = np.argsort(chunk)[::-1] 
        top_11 = sorted_indices[:11]
        top_11_indices_pred.append(top_11)
    for chunk, indices in zip(y_test_chunks, top_11_indices_pred):
        sorted_chunk = np.zeros_like(chunk)
        sorted_chunk[:len(indices)] = chunk[indices]  # Assign top 11 values
        remaining_indices = [i for i in range(chunk_size) if i not in indices]
        sorted_chunk[len(indices):] = chunk[remaining_indices]  # Assign rest
        sorted_y_pred_chunks.append(sorted_chunk)  

    top_11_indices_test = []
    for chunk in y_test_chunks:
        sorted_indices = np.argsort(chunk)[::-1]  # Sort actual values in descending order
        top_11 = sorted_indices[:11]
        top_11_indices_test.append(top_11)
        sorted_y_test_chunks.append(chunk[sorted_indices])  # Sort the y_test values correctly
    
    return sorted_y_test_chunks, sorted_y_pred_chunks, top_11_indices_pred
y_test=y_test.flatten() 
y_pred=y_pred.flatten()
sorted_y_test_chunks, sorted_y_pred_chunks, top_11_indices_pred = process_chunks(y_pred, y_test)
mae_list = []
sum1_list = []

for i, (sorted_y_pred_chunk, sorted_y_test_chunk) in enumerate(zip(sorted_y_pred_chunks, sorted_y_test_chunks)):
    sum1 = sorted_y_test_chunk[0] * 2 + sorted_y_test_chunk[1] * 1.5 + np.sum(sorted_y_test_chunk[2:11]) 
    sum2 = sorted_y_pred_chunk[0] * 2 + sorted_y_pred_chunk[1] * 1.5 + np.sum(sorted_y_pred_chunk[2:11]) 

    error = np.abs(sum1 - sum2) 
    mae_list.append(error)
    sum1_list.append(sum1)

    print(f"Chunk {i+1} Error: {error}, True Sum: {sum1}, Predicted Sum: {sum2}")
print("Mean Absolute Error (MAE):", np.mean(np.array(mae_list)))
print("Average Dream Team Points in ODI:", np.mean(np.array(sum1_list)))
# Out:
# Chunk 1 Error: 230.0, True Sum: 1232.0, Predicted Sum: 1002.0
# Chunk 2 Error: 608.0, True Sum: 1112.0, Predicted Sum: 504.0
# Chunk 3 Error: 543.5, True Sum: 1146.5, Predicted Sum: 603.0
# Chunk 4 Error: 399.0, True Sum: 939.5, Predicted Sum: 540.5
# Chunk 5 Error: 246.0, True Sum: 886.0, Predicted Sum: 640.0
# Chunk 6 Error: 358.5, True Sum: 1076.0, Predicted Sum: 717.5
# Chunk 7 Error: 281.0, True Sum: 1052.5, Predicted Sum: 771.5
# Chunk 8 Error: 403.5, True Sum: 1218.5, Predicted Sum: 815.0
# Chunk 9 Error: 286.5, True Sum: 745.0, Predicted Sum: 458.5
# Chunk 10 Error: 255.5, True Sum: 691.5, Predicted Sum: 436.0
# Chunk 11 Error: 473.5, True Sum: 1030.0, Predicted Sum: 556.5
# Chunk 12 Error: 482.0, True Sum: 921.5, Predicted Sum: 439.5
# Chunk 13 Error: 170.5, True Sum: 681.5, Predicted Sum: 511.0
# Chunk 14 Error: 607.0, True Sum: 936.0, Predicted Sum: 329.0
# Chunk 15 Error: 306.0, True Sum: 1065.0, Predicted Sum: 759.0
# Chunk 16 Error: 275.0, True Sum: 1082.0, Predicted Sum: 807.0
# Chunk 17 Error: 364.0, True Sum: 986.5, Predicted Sum: 622.5
# Chunk 18 Error: 342.0, True Sum: 1051.5, Predicted Sum: 709.5
# Chunk 19 Error: 346.0, True Sum: 1132.5, Predicted Sum: 786.5
# Chunk 20 Error: 426.0, True Sum: 1037.0, Predicted Sum: 611.0
# Chunk 21 Error: 471.5, True Sum: 1055.5, Predicted Sum: 584.0
# Chunk 22 Error: 412.5, True Sum: 1124.5, Predicted Sum: 712.0
# Chunk 23 Error: 505.5, True Sum: 910.0, Predicted Sum: 404.5
# Chunk 24 Error: 304.5, True Sum: 828.5, Predicted Sum: 524.0
# Chunk 25 Error: 300.0, True Sum: 1048.5, Predicted Sum: 748.5
# Chunk 26 Error: 563.0, True Sum: 1143.5, Predicted Sum: 580.5
# Chunk 27 Error: 253.5, True Sum: 873.0, Predicted Sum: 619.5
# Chunk 28 Error: 319.0, True Sum: 1006.5, Predicted Sum: 687.5
# Chunk 29 Error: 239.5, True Sum: 879.5, Predicted Sum: 640.0
# Chunk 30 Error: 353.5, True Sum: 972.0, Predicted Sum: 618.5
# Chunk 31 Error: 314.0, True Sum: 844.0, Predicted Sum: 530.0
# Chunk 32 Error: 552.5, True Sum: 1210.5, Predicted Sum: 658.0
# Chunk 33 Error: 336.0, True Sum: 913.5, Predicted Sum: 577.5
# Chunk 34 Error: 266.0, True Sum: 1135.0, Predicted Sum: 869.0
# Chunk 35 Error: 279.0, True Sum: 1022.5, Predicted Sum: 743.5
# Chunk 36 Error: 306.5, True Sum: 1076.0, Predicted Sum: 769.5
# Chunk 37 Error: 645.5, True Sum: 1093.5, Predicted Sum: 448.0
# Chunk 38 Error: 235.5, True Sum: 319.5, Predicted Sum: 84.0
# Chunk 39 Error: 377.5, True Sum: 721.5, Predicted Sum: 344.0
# Chunk 40 Error: 305.0, True Sum: 1061.0, Predicted Sum: 756.0
# Chunk 41 Error: 373.5, True Sum: 885.5, Predicted Sum: 512.0
# Chunk 42 Error: 452.0, True Sum: 1123.5, Predicted Sum: 671.5
# Chunk 43 Error: 356.5, True Sum: 1178.0, Predicted Sum: 821.5
# Chunk 44 Error: 401.5, True Sum: 973.0, Predicted Sum: 571.5
# Chunk 45 Error: 282.5, True Sum: 837.0, Predicted Sum: 554.5
# Chunk 46 Error: 242.5, True Sum: 727.5, Predicted Sum: 485.0
# Chunk 47 Error: 433.0, True Sum: 1253.5, Predicted Sum: 820.5
# Chunk 48 Error: 493.5, True Sum: 940.0, Predicted Sum: 446.5
# Chunk 49 Error: 532.5, True Sum: 912.5, Predicted Sum: 380.0
# Chunk 50 Error: 363.0, True Sum: 774.5, Predicted Sum: 411.5
# Chunk 51 Error: 287.0, True Sum: 942.0, Predicted Sum: 655.0
# Chunk 52 Error: 249.5, True Sum: 1071.0, Predicted Sum: 821.5
# Chunk 53 Error: 204.5, True Sum: 903.5, Predicted Sum: 699.0
# Chunk 54 Error: 364.5, True Sum: 927.5, Predicted Sum: 563.0
# Chunk 55 Error: 417.5, True Sum: 991.5, Predicted Sum: 574.0
# Chunk 56 Error: 283.5, True Sum: 902.0, Predicted Sum: 618.5
# Chunk 57 Error: 367.5, True Sum: 1079.0, Predicted Sum: 711.5
# Chunk 58 Error: 244.5, True Sum: 897.0, Predicted Sum: 652.5
# Chunk 59 Error: 683.5, True Sum: 1436.5, Predicted Sum: 753.0
# Chunk 60 Error: 299.0, True Sum: 1202.5, Predicted Sum: 903.5
# Chunk 61 Error: 474.5, True Sum: 1175.5, Predicted Sum: 701.0
# Chunk 62 Error: 508.5, True Sum: 740.5, Predicted Sum: 232.0
# Chunk 63 Error: 626.5, True Sum: 1165.5, Predicted Sum: 539.0
# Chunk 64 Error: 549.5, True Sum: 1073.0, Predicted Sum: 523.5
# Chunk 65 Error: 665.5, True Sum: 1431.0, Predicted Sum: 765.5
# Chunk 66 Error: 724.0, True Sum: 1297.5, Predicted Sum: 573.5
# Chunk 67 Error: 270.0, True Sum: 1040.0, Predicted Sum: 770.0
# Chunk 68 Error: 298.5, True Sum: 863.5, Predicted Sum: 565.0
# Chunk 69 Error: 403.0, True Sum: 1385.5, Predicted Sum: 982.5
# Chunk 70 Error: 390.0, True Sum: 1031.5, Predicted Sum: 641.5
# Chunk 71 Error: 297.5, True Sum: 1066.0, Predicted Sum: 768.5
# Chunk 72 Error: 420.0, True Sum: 947.5, Predicted Sum: 527.5
# Chunk 73 Error: 257.5, True Sum: 1059.0, Predicted Sum: 801.5
# Chunk 74 Error: 513.0, True Sum: 1234.5, Predicted Sum: 721.5
# Chunk 75 Error: 514.5, True Sum: 1042.0, Predicted Sum: 527.5
# Chunk 76 Error: 451.5, True Sum: 1064.0, Predicted Sum: 612.5
# Chunk 77 Error: 371.5, True Sum: 1110.5, Predicted Sum: 739.0
# Chunk 78 Error: 326.0, True Sum: 1146.5, Predicted Sum: 820.5
# Chunk 79 Error: 284.5, True Sum: 1127.5, Predicted Sum: 843.0
# Chunk 80 Error: 755.0, True Sum: 1444.0, Predicted Sum: 689.0
# Chunk 81 Error: 199.5, True Sum: 565.5, Predicted Sum: 366.0
# Chunk 82 Error: 141.0, True Sum: 900.0, Predicted Sum: 759.0
# Chunk 83 Error: 146.0, True Sum: 793.5, Predicted Sum: 647.5
# Chunk 84 Error: 358.5, True Sum: 1108.0, Predicted Sum: 749.5
# Chunk 85 Error: 434.0, True Sum: 1221.0, Predicted Sum: 787.0
# Chunk 86 Error: 384.0, True Sum: 794.5, Predicted Sum: 410.5
# Chunk 87 Error: 218.0, True Sum: 997.5, Predicted Sum: 779.5
# Chunk 88 Error: 296.0, True Sum: 494.0, Predicted Sum: 198.0
# Chunk 89 Error: 237.0, True Sum: 780.5, Predicted Sum: 543.5
# Chunk 90 Error: 281.0, True Sum: 1040.5, Predicted Sum: 759.5
# Chunk 91 Error: 351.5, True Sum: 977.0, Predicted Sum: 625.5
# Chunk 92 Error: 392.0, True Sum: 803.0, Predicted Sum: 411.0
# Chunk 93 Error: 368.0, True Sum: 1058.5, Predicted Sum: 690.5
# Chunk 94 Error: 240.5, True Sum: 896.5, Predicted Sum: 656.0
# Chunk 95 Error: 501.0, True Sum: 907.0, Predicted Sum: 406.0
# Chunk 96 Error: 510.0, True Sum: 959.0, Predicted Sum: 449.0
# Chunk 97 Error: 298.5, True Sum: 1060.0, Predicted Sum: 761.5
# Chunk 98 Error: 138.5, True Sum: 262.5, Predicted Sum: 124.0
# Chunk 99 Error: 498.0, True Sum: 1226.5, Predicted Sum: 728.5
# Chunk 100 Error: 320.5, True Sum: 872.5, Predicted Sum: 552.0
# Chunk 101 Error: 314.0, True Sum: 1182.0, Predicted Sum: 868.0
# Chunk 102 Error: 360.5, True Sum: 1490.0, Predicted Sum: 1129.5
# Chunk 103 Error: 139.0, True Sum: 611.0, Predicted Sum: 472.0
# Chunk 104 Error: 551.0, True Sum: 1415.5, Predicted Sum: 864.5
# Chunk 105 Error: 498.0, True Sum: 935.0, Predicted Sum: 437.0
# Chunk 106 Error: 380.5, True Sum: 721.0, Predicted Sum: 340.5
# Chunk 107 Error: 353.5, True Sum: 1157.0, Predicted Sum: 803.5
# Chunk 108 Error: 306.0, True Sum: 960.5, Predicted Sum: 654.5
# Chunk 109 Error: 376.0, True Sum: 1310.5, Predicted Sum: 934.5
# Chunk 110 Error: 268.5, True Sum: 1100.0, Predicted Sum: 831.5
# Chunk 111 Error: 208.0, True Sum: 1130.0, Predicted Sum: 922.0
# Chunk 112 Error: 367.0, True Sum: 828.0, Predicted Sum: 461.0
# Chunk 113 Error: 262.5, True Sum: 553.5, Predicted Sum: 291.0
# Chunk 114 Error: 516.5, True Sum: 1372.5, Predicted Sum: 856.0
# Chunk 115 Error: 695.5, True Sum: 905.0, Predicted Sum: 209.5
# Chunk 116 Error: 200.0, True Sum: 1153.0, Predicted Sum: 953.0
# Chunk 117 Error: 531.0, True Sum: 1040.0, Predicted Sum: 509.0
# Chunk 118 Error: 165.5, True Sum: 936.5, Predicted Sum: 771.0
# Chunk 119 Error: 403.5, True Sum: 1083.0, Predicted Sum: 679.5
# Chunk 120 Error: 229.0, True Sum: 1123.0, Predicted Sum: 894.0
# Chunk 121 Error: 267.0, True Sum: 726.5, Predicted Sum: 459.5
# Chunk 122 Error: 366.5, True Sum: 1138.0, Predicted Sum: 771.5
# Chunk 123 Error: 295.5, True Sum: 958.0, Predicted Sum: 662.5
# Chunk 124 Error: 206.5, True Sum: 909.5, Predicted Sum: 703.0
# Chunk 125 Error: 299.0, True Sum: 910.5, Predicted Sum: 611.5
# Chunk 126 Error: 325.5, True Sum: 987.5, Predicted Sum: 662.0
# Chunk 127 Error: 447.5, True Sum: 1091.5, Predicted Sum: 644.0
# Chunk 128 Error: 455.0, True Sum: 1169.0, Predicted Sum: 714.0
# Chunk 129 Error: 418.0, True Sum: 1038.5, Predicted Sum: 620.5
# Chunk 130 Error: 298.5, True Sum: 532.5, Predicted Sum: 234.0
# Chunk 131 Error: 330.0, True Sum: 1096.5, Predicted Sum: 766.5
# Chunk 132 Error: 665.5, True Sum: 1150.0, Predicted Sum: 484.5
# Chunk 133 Error: 425.0, True Sum: 1009.0, Predicted Sum: 584.0
# Chunk 134 Error: 636.5, True Sum: 1285.0, Predicted Sum: 648.5
# Chunk 135 Error: 186.5, True Sum: 898.0, Predicted Sum: 711.5
# Chunk 136 Error: 162.0, True Sum: 523.5, Predicted Sum: 361.5
# Chunk 137 Error: 613.5, True Sum: 1292.5, Predicted Sum: 679.0
# Chunk 138 Error: 555.5, True Sum: 1041.5, Predicted Sum: 486.0
# Chunk 139 Error: 393.0, True Sum: 1142.5, Predicted Sum: 749.5
# Chunk 140 Error: 395.0, True Sum: 965.0, Predicted Sum: 570.0
# Chunk 141 Error: 282.0, True Sum: 1000.0, Predicted Sum: 718.0
# Chunk 142 Error: 577.0, True Sum: 1099.0, Predicted Sum: 522.0
# Chunk 143 Error: 376.5, True Sum: 921.0, Predicted Sum: 544.5
# Chunk 144 Error: 559.0, True Sum: 1130.5, Predicted Sum: 571.5
# Chunk 145 Error: 222.0, True Sum: 993.5, Predicted Sum: 771.5
# Chunk 146 Error: 308.5, True Sum: 1010.0, Predicted Sum: 701.5
# Chunk 147 Error: 365.0, True Sum: 915.5, Predicted Sum: 550.5
# Chunk 148 Error: 398.0, True Sum: 1233.5, Predicted Sum: 835.5
# Chunk 149 Error: 367.0, True Sum: 1207.0, Predicted Sum: 840.0
# Chunk 150 Error: 447.0, True Sum: 897.5, Predicted Sum: 450.5
# Chunk 151 Error: 485.0, True Sum: 1079.5, Predicted Sum: 594.5
# Chunk 152 Error: 385.0, True Sum: 1186.0, Predicted Sum: 801.0
# Chunk 153 Error: 308.0, True Sum: 958.0, Predicted Sum: 650.0
# Chunk 154 Error: 340.5, True Sum: 859.0, Predicted Sum: 518.5
# Chunk 155 Error: 284.0, True Sum: 926.0, Predicted Sum: 642.0
# Chunk 156 Error: 631.0, True Sum: 1284.0, Predicted Sum: 653.0
# Chunk 157 Error: 268.0, True Sum: 1210.0, Predicted Sum: 942.0
# Chunk 158 Error: 889.0, True Sum: 1296.0, Predicted Sum: 407.0
# Chunk 159 Error: 529.0, True Sum: 1235.0, Predicted Sum: 706.0
# Chunk 160 Error: 260.5, True Sum: 1204.0, Predicted Sum: 943.5
# Chunk 161 Error: 279.5, True Sum: 922.5, Predicted Sum: 643.0
# Chunk 162 Error: 316.0, True Sum: 928.0, Predicted Sum: 612.0
# Chunk 163 Error: 599.0, True Sum: 986.0, Predicted Sum: 387.0
# Chunk 164 Error: 352.5, True Sum: 1056.0, Predicted Sum: 703.5
# Chunk 165 Error: 275.5, True Sum: 626.5, Predicted Sum: 351.0
# Chunk 166 Error: 523.0, True Sum: 908.0, Predicted Sum: 385.0
# Chunk 167 Error: 331.5, True Sum: 1026.5, Predicted Sum: 695.0
# Chunk 168 Error: 339.5, True Sum: 877.5, Predicted Sum: 538.0
# Chunk 169 Error: 544.5, True Sum: 1094.5, Predicted Sum: 550.0
# Chunk 170 Error: 320.0, True Sum: 1157.5, Predicted Sum: 837.5
# Chunk 171 Error: 808.0, True Sum: 1265.0, Predicted Sum: 457.0
# Chunk 172 Error: 328.0, True Sum: 948.0, Predicted Sum: 620.0
# Chunk 173 Error: 296.0, True Sum: 1317.0, Predicted Sum: 1021.0
# Chunk 174 Error: 364.0, True Sum: 822.0, Predicted Sum: 458.0
# Chunk 175 Error: 392.0, True Sum: 1395.0, Predicted Sum: 1003.0
# Chunk 176 Error: 352.0, True Sum: 849.5, Predicted Sum: 497.5
# Chunk 177 Error: 659.5, True Sum: 1176.5, Predicted Sum: 517.0
# Chunk 178 Error: 358.0, True Sum: 925.0, Predicted Sum: 567.0
# Chunk 179 Error: 349.0, True Sum: 466.0, Predicted Sum: 117.0
# Chunk 180 Error: 339.5, True Sum: 1242.0, Predicted Sum: 902.5
# Chunk 181 Error: 312.0, True Sum: 1100.5, Predicted Sum: 788.5
# Chunk 182 Error: 492.5, True Sum: 1060.0, Predicted Sum: 567.5
# Chunk 183 Error: 359.0, True Sum: 961.5, Predicted Sum: 602.5
# Chunk 184 Error: 387.0, True Sum: 1244.0, Predicted Sum: 857.0
# Chunk 185 Error: 412.5, True Sum: 1448.0, Predicted Sum: 1035.5
# Chunk 186 Error: 308.0, True Sum: 1224.5, Predicted Sum: 916.5
# Chunk 187 Error: 451.0, True Sum: 1146.5, Predicted Sum: 695.5
# Chunk 188 Error: 503.5, True Sum: 1214.5, Predicted Sum: 711.0
# Chunk 189 Error: 398.5, True Sum: 1231.5, Predicted Sum: 833.0
# Chunk 190 Error: 294.0, True Sum: 1165.5, Predicted Sum: 871.5
# Chunk 191 Error: 470.0, True Sum: 812.5, Predicted Sum: 342.5
# Chunk 192 Error: 218.0, True Sum: 896.5, Predicted Sum: 678.5
# Chunk 193 Error: 158.0, True Sum: 739.0, Predicted Sum: 581.0
# Chunk 194 Error: 405.5, True Sum: 1000.5, Predicted Sum: 595.0
# Chunk 195 Error: 470.0, True Sum: 1240.5, Predicted Sum: 770.5
# Chunk 196 Error: 161.0, True Sum: 987.0, Predicted Sum: 826.0
# Chunk 197 Error: 279.5, True Sum: 1022.5, Predicted Sum: 743.0
# Chunk 198 Error: 221.5, True Sum: 854.5, Predicted Sum: 633.0
# Chunk 199 Error: 306.5, True Sum: 1324.0, Predicted Sum: 1017.5
# Chunk 200 Error: 493.5, True Sum: 1106.5, Predicted Sum: 613.0
# Chunk 201 Error: 459.0, True Sum: 847.5, Predicted Sum: 388.5
# Chunk 202 Error: 198.0, True Sum: 1070.0, Predicted Sum: 872.0
# Chunk 203 Error: 296.5, True Sum: 781.5, Predicted Sum: 485.0
# Chunk 204 Error: 318.5, True Sum: 825.5, Predicted Sum: 507.0
# Chunk 205 Error: 347.5, True Sum: 1104.0, Predicted Sum: 756.5
# Chunk 206 Error: 763.0, True Sum: 1204.5, Predicted Sum: 441.5
# Chunk 207 Error: 230.5, True Sum: 1219.5, Predicted Sum: 989.0
# Chunk 208 Error: 286.5, True Sum: 1219.5, Predicted Sum: 933.0
# Chunk 209 Error: 580.0, True Sum: 951.5, Predicted Sum: 371.5
# Chunk 210 Error: 459.0, True Sum: 1213.5, Predicted Sum: 754.5
# Chunk 211 Error: 683.0, True Sum: 1166.5, Predicted Sum: 483.5
# Chunk 212 Error: 569.0, True Sum: 1361.0, Predicted Sum: 792.0
# Chunk 213 Error: 267.5, True Sum: 1044.0, Predicted Sum: 776.5
# Chunk 214 Error: 381.5, True Sum: 916.0, Predicted Sum: 534.5
# Chunk 215 Error: 396.5, True Sum: 819.5, Predicted Sum: 423.0
# Chunk 216 Error: 412.5, True Sum: 921.0, Predicted Sum: 508.5
# Chunk 217 Error: 436.5, True Sum: 1017.0, Predicted Sum: 580.5
# Chunk 218 Error: 387.0, True Sum: 985.0, Predicted Sum: 598.0
# Chunk 219 Error: 680.0, True Sum: 1319.5, Predicted Sum: 639.5
# Chunk 220 Error: 392.0, True Sum: 1020.0, Predicted Sum: 628.0
# Chunk 221 Error: 323.5, True Sum: 1207.5, Predicted Sum: 884.0
# Chunk 222 Error: 350.5, True Sum: 1111.5, Predicted Sum: 761.0
# Chunk 223 Error: 352.0, True Sum: 1389.0, Predicted Sum: 1037.0
# Chunk 224 Error: 327.0, True Sum: 1104.5, Predicted Sum: 777.5
# Chunk 225 Error: 244.0, True Sum: 738.0, Predicted Sum: 494.0
# Chunk 226 Error: 262.5, True Sum: 925.5, Predicted Sum: 663.0
# Chunk 227 Error: 208.0, True Sum: 1295.5, Predicted Sum: 1087.5
# Chunk 228 Error: 419.5, True Sum: 1111.5, Predicted Sum: 692.0
# Chunk 229 Error: 363.5, True Sum: 1055.0, Predicted Sum: 691.5
# Chunk 230 Error: 359.5, True Sum: 966.0, Predicted Sum: 606.5
# Chunk 231 Error: 515.5, True Sum: 1231.0, Predicted Sum: 715.5
# Chunk 232 Error: 525.5, True Sum: 1132.5, Predicted Sum: 607.0
# Chunk 233 Error: 527.0, True Sum: 1146.5, Predicted Sum: 619.5
# Chunk 234 Error: 322.5, True Sum: 960.5, Predicted Sum: 638.0
# Chunk 235 Error: 603.0, True Sum: 1279.0, Predicted Sum: 676.0
# Chunk 236 Error: 504.5, True Sum: 1150.0, Predicted Sum: 645.5
# Chunk 237 Error: 230.0, True Sum: 1118.5, Predicted Sum: 888.5
# Chunk 238 Error: 232.0, True Sum: 950.5, Predicted Sum: 718.5
# Chunk 239 Error: 422.5, True Sum: 1104.5, Predicted Sum: 682.0
# Chunk 240 Error: 239.5, True Sum: 948.0, Predicted Sum: 708.5
# Chunk 241 Error: 421.5, True Sum: 1333.5, Predicted Sum: 912.0
# Chunk 242 Error: 488.5, True Sum: 1476.5, Predicted Sum: 988.0
# Chunk 243 Error: 685.0, True Sum: 1030.5, Predicted Sum: 345.5
# Chunk 244 Error: 385.0, True Sum: 1069.5, Predicted Sum: 684.5
# Chunk 245 Error: 709.0, True Sum: 1371.5, Predicted Sum: 662.5
# Chunk 246 Error: 498.5, True Sum: 901.0, Predicted Sum: 402.5
# Chunk 247 Error: 565.0, True Sum: 1193.0, Predicted Sum: 628.0
# Chunk 248 Error: 558.5, True Sum: 1014.0, Predicted Sum: 455.5
# Chunk 249 Error: 439.5, True Sum: 1019.0, Predicted Sum: 579.5
# Chunk 250 Error: 265.5, True Sum: 589.0, Predicted Sum: 323.5
# Chunk 251 Error: 726.5, True Sum: 1075.0, Predicted Sum: 348.5
# Chunk 252 Error: 433.5, True Sum: 1073.5, Predicted Sum: 640.0
# Chunk 253 Error: 535.0, True Sum: 1157.5, Predicted Sum: 622.5
# Chunk 254 Error: 240.0, True Sum: 683.5, Predicted Sum: 443.5
# Chunk 255 Error: 250.0, True Sum: 1242.0, Predicted Sum: 992.0
# Chunk 256 Error: 345.0, True Sum: 645.0, Predicted Sum: 300.0
# Chunk 257 Error: 237.0, True Sum: 735.0, Predicted Sum: 498.0
# Chunk 258 Error: 456.0, True Sum: 914.0, Predicted Sum: 458.0
# Chunk 259 Error: 382.5, True Sum: 836.5, Predicted Sum: 454.0
# Chunk 260 Error: 357.0, True Sum: 1031.5, Predicted Sum: 674.5
# Chunk 261 Error: 821.5, True Sum: 1263.5, Predicted Sum: 442.0
# Chunk 262 Error: 493.5, True Sum: 882.5, Predicted Sum: 389.0
# Chunk 263 Error: 674.0, True Sum: 1200.0, Predicted Sum: 526.0
# Chunk 264 Error: 591.0, True Sum: 1080.5, Predicted Sum: 489.5
# Chunk 265 Error: 432.5, True Sum: 624.0, Predicted Sum: 191.5
# Chunk 266 Error: 564.5, True Sum: 1112.5, Predicted Sum: 548.0
# Chunk 267 Error: 307.5, True Sum: 1288.0, Predicted Sum: 980.5
# Chunk 268 Error: 484.0, True Sum: 1198.5, Predicted Sum: 714.5
# Chunk 269 Error: 259.0, True Sum: 505.0, Predicted Sum: 246.0
# Chunk 270 Error: 688.0, True Sum: 1083.0, Predicted Sum: 395.0
# Chunk 271 Error: 446.0, True Sum: 903.0, Predicted Sum: 457.0
# Chunk 272 Error: 567.5, True Sum: 1025.5, Predicted Sum: 458.0
# Chunk 273 Error: 266.5, True Sum: 465.5, Predicted Sum: 199.0
# Chunk 274 Error: 336.5, True Sum: 698.0, Predicted Sum: 361.5
# Chunk 275 Error: 308.5, True Sum: 1119.0, Predicted Sum: 810.5
# Chunk 276 Error: 223.0, True Sum: 715.0, Predicted Sum: 492.0
# Chunk 277 Error: 443.0, True Sum: 970.5, Predicted Sum: 527.5
# Chunk 278 Error: 346.0, True Sum: 809.5, Predicted Sum: 463.5
# Chunk 279 Error: 782.0, True Sum: 1116.5, Predicted Sum: 334.5
# Chunk 280 Error: 461.5, True Sum: 1111.5, Predicted Sum: 650.0
# Chunk 281 Error: 592.5, True Sum: 1101.0, Predicted Sum: 508.5
# Chunk 282 Error: 342.0, True Sum: 1058.0, Predicted Sum: 716.0
# Chunk 283 Error: 446.5, True Sum: 1071.5, Predicted Sum: 625.0
# Chunk 284 Error: 625.5, True Sum: 968.0, Predicted Sum: 342.5
# Chunk 285 Error: 297.5, True Sum: 618.5, Predicted Sum: 321.0
# Chunk 286 Error: 357.5, True Sum: 1062.0, Predicted Sum: 704.5
# Chunk 287 Error: 229.0, True Sum: 625.5, Predicted Sum: 396.5
# Chunk 288 Error: 272.0, True Sum: 976.0, Predicted Sum: 704.0
# Chunk 289 Error: 227.0, True Sum: 1149.5, Predicted Sum: 922.5
# Chunk 290 Error: 313.5, True Sum: 767.0, Predicted Sum: 453.5
# Chunk 291 Error: 150.5, True Sum: 923.5, Predicted Sum: 773.0
# Chunk 292 Error: 312.0, True Sum: 964.5, Predicted Sum: 652.5
# Chunk 293 Error: 287.5, True Sum: 653.0, Predicted Sum: 365.5
# Chunk 294 Error: 417.5, True Sum: 993.0, Predicted Sum: 575.5
# Chunk 295 Error: 218.5, True Sum: 622.5, Predicted Sum: 404.0
# Chunk 296 Error: 194.0, True Sum: 1097.5, Predicted Sum: 903.5
# Chunk 297 Error: 626.5, True Sum: 876.5, Predicted Sum: 250.0
# Chunk 298 Error: 145.0, True Sum: 775.5, Predicted Sum: 630.5
# Chunk 299 Error: 101.5, True Sum: 788.5, Predicted Sum: 687.0
# Chunk 300 Error: 396.0, True Sum: 839.5, Predicted Sum: 443.5
# Chunk 301 Error: 503.0, True Sum: 1070.0, Predicted Sum: 567.0
# Chunk 302 Error: 132.0, True Sum: 861.0, Predicted Sum: 729.0
# Chunk 303 Error: 625.0, True Sum: 934.5, Predicted Sum: 309.5
# Chunk 304 Error: 421.0, True Sum: 1096.0, Predicted Sum: 675.0
# Chunk 305 Error: 498.5, True Sum: 1081.0, Predicted Sum: 582.5
# Chunk 306 Error: 246.0, True Sum: 1110.5, Predicted Sum: 864.5
# Chunk 307 Error: 293.0, True Sum: 911.5, Predicted Sum: 618.5
# Chunk 308 Error: 284.0, True Sum: 990.0, Predicted Sum: 706.0
# Chunk 309 Error: 525.0, True Sum: 1065.0, Predicted Sum: 540.0
# Chunk 310 Error: 738.5, True Sum: 1237.5, Predicted Sum: 499.0
# Chunk 311 Error: 242.0, True Sum: 1057.0, Predicted Sum: 815.0
# Chunk 312 Error: 258.5, True Sum: 1110.5, Predicted Sum: 852.0
# Chunk 313 Error: 409.0, True Sum: 1084.5, Predicted Sum: 675.5
# Chunk 314 Error: 262.0, True Sum: 836.5, Predicted Sum: 574.5
# Chunk 315 Error: 352.5, True Sum: 847.5, Predicted Sum: 495.0
# Chunk 316 Error: 495.5, True Sum: 985.0, Predicted Sum: 489.5
# Chunk 317 Error: 373.5, True Sum: 1130.0, Predicted Sum: 756.5
# Chunk 318 Error: 234.0, True Sum: 962.5, Predicted Sum: 728.5
# Mean Absolute Error (MAE): 388.87578616352204
# Average Dream Team Points in ODI: 1014.0345911949686

# %%
print("Mean of y_test:", np.mean(y_test))
print("Std dev of y_test:", np.std(y_test))
# Out:
# Mean of y_test: 44.20257142857143
# Std dev of y_test: 41.11478488627781

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 40.70595576808319

# %%
import pickle
pickle.dump(model, open("xgb_model.pkl", "wb"))

# %%
import os
import json
import pandas as pd

# Define the folder names and their corresponding csv folder mapping
folder_mapping = {
    'data1_json': 'csv1',
    'data2_json': 'csv2',
    'data3_json': 'csv3'
}

# Initialize a list to store the results
rows = []

# Base directory (adjust if needed)
base_dir = os.getcwd()  # or specify the directory where data folders are located

# Iterate through each folder in the mapping
for folder, csv_folder in folder_mapping.items():
    folder_path = os.path.join(base_dir, folder)
    # List all files that end with .json
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_full_path = os.path.join(folder_path, filename)
            # Open and load the JSON data
            with open(file_full_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
            
            # Extract teams and date. 
            # Assuming teams is a list under info -> teams and date is the first element in info -> dates.
            teams = data.get('info', {}).get('teams', [])
            date_list = data.get('info', {}).get('dates', [])
            
            # Assign team1 and team2 based on the order in the list (if available)
            team1 = teams[0] if len(teams) > 0 else None
            team2 = teams[1] if len(teams) > 1 else None
            
            # Get the first date from the dates list
            date = date_list[0] if date_list else None
            
            # Create the new file path as described: dt/{csv_folder}/{filename with .csv extension}
            base_file, _ = os.path.splitext(filename)
            new_filename = base_file + '.csv'
            new_file_path = os.path.join('dt', csv_folder, new_filename)
            
            # Append the row details to the list
            rows.append({
                'file_path': new_file_path,
                'team1': team1,
                'team2': team2,
                'date': date
            })

# Create DataFrame
df = pd.DataFrame(rows)
print(df)

# Optionally, save the dataframe to a CSV file
df.to_csv('combined_data2.csv', index=False)
# Out:
#                 file_path        team1                 team2        date
# 0       dt/csv1/65240.csv        Kenya          South Africa  2003-02-12
# 1       dt/csv1/66357.csv     Pakistan             Sri Lanka  2003-05-10
# 2       dt/csv1/65708.csv     Pakistan            Bangladesh  2004-07-17
# 3       dt/csv1/64825.csv    Australia           West Indies  2003-05-30
# 4       dt/csv1/65255.csv      England              Pakistan  2003-02-22
# ...                   ...          ...                   ...         ...
# 2384  dt/csv3/1322278.csv        India           New Zealand  2022-11-25
# 2385  dt/csv3/1146722.csv   Bangladesh           West Indies  2018-07-28
# 2386  dt/csv3/1020037.csv  New Zealand          South Africa  2017-03-01
# 2387  dt/csv3/1377757.csv     Scotland  United Arab Emirates  2023-06-23
# 2388  dt/csv3/1377752.csv      Ireland              Scotland  2023-06-21
#
# [2389 rows x 4 columns]
